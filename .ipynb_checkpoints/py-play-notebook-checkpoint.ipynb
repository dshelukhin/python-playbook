# %%
import sys
import os
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(100,4).cumsum(0))

# %%
df.plot(subplots=False, sharey=True, legend=False)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('2015-01-01', periods=1000))

# %%
ts.head()
# Out:
# 2015-01-01    2.331636
# 2015-01-02   -1.251924
# 2015-01-03   -1.117794
# 2015-01-04    0.088020
# 2015-01-05    0.106120
# Freq: D, dtype: float64

# %%
ts.groupby(lambda x: x.year).count()
# Out:
# 2015    365
# 2016    366
# 2017    269
# dtype: int64

# %%
datetime.now().year
# Out:
# 2017

# %%
ts.plot()
