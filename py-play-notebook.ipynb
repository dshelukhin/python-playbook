# %%
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(100,4).cumsum(0))

# %%
df.plot(subplots=False, sharey=True, legend=False)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('2015-01-01', periods=1000))

# %%
ts.head()
# Out:
# 2015-01-01   -0.225449
# 2015-01-02   -0.491376
# 2015-01-03    0.612127
# 2015-01-04    1.491980
# 2015-01-05   -1.023795
# Freq: D, dtype: float64

# %%
ts.groupby(lambda x: x.year).mean()
# Out:
# 2015    0.008027
# 2016    0.050502
# 2017    0.144169
# dtype: float64

# %%
datetime.now().year
# Out:
# 2017
